# %%
import streamlit as st
import requests
import datetime
from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI
from langchain_community.vectorstores import FAISS
from langchain_community.document_loaders import PyPDFLoader
# Try this if the first one fails
from langchain_tavily import TavilySearch
from langchain.tools import create_retriever_tool
from langchain.agents import AgentExecutor, create_tool_calling_agent
from langchain import hub
from langchain_core.tools import tool
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 9
#       7 # Try this if the first one fails
#       8 from langchain_tavily import TavilySearch
# ----> 9 from langchain.tools import create_retriever_tool
#      10 from langchain.agents import AgentExecutor, create_tool_calling_agent
#      11 from langchain import hub
#
# ImportError: cannot import name 'create_retriever_tool' from 'langchain.tools' (/Users/vishal/Documents/python_projects/AI Chatbot of Vishal/my-ai-resume/.venv/lib/python3.12/site-packages/langchain/tools/__init__.py)

# %%
# Out:
# zsh:1: command not found: pip
